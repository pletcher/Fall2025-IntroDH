# %% [markdown]
# # Lab Demo

# %%
import json
import re

import requests

from bs4 import BeautifulSoup

my_network = {
    "title": "Digital Humanities",
    "content": "Digital humanities is...",
    "url": "https://en.wikipedia.org/wiki/Digital_humanities",
    "links": [],
}

my_network_list = [
    {
        "title": "Digital Humanities",
        "content": "Digital humanities is...",
        "url": "https://en.wikipedia.org/wiki/Digital_humanities",
        "links": ["https://en.wikipedia.org/wiki/Computing"],
    },
    {
        "title": "Computing",
        "content": "Computing is...",
        "url": "https://en.wikipedia.org/wiki/Computing",
        "links": [],
    },
]


def create_node(response: requests.Response):
    page = BeautifulSoup(response.content)

    title = get_title(page)
    content = get_content(page)
    url = response.url
    links = get_links(page)

    return {"title": title, "content": content, "url": url, "links": links}


def get_content(page: BeautifulSoup):
    body = page.find("div", {"id": "mw-content-text"})

    if body is not None:
        return body.text


def get_links(page: BeautifulSoup):
    body = page.find("div", {"id": "mw-content-text"})

    if body is not None:
        links = body.find_all(
            "a",
            attrs={
                "href": re.compile("^/wiki/*"),
                "class": re.compile(r"^(?!mw\-file\-description)"),
            },
            limit=5,
        )

        return [f"https://en.wikipedia.org{l['href']}" for l in links]


def get_title(page: BeautifulSoup):
    h1 = page.find("h1", {"id": "firstHeading"})

    if h1 is not None:
        return h1.text

# %%
import random
import time

from collections import deque

MY_NETWORK = []
STARTING_URL = "https://en.wikipedia.org/wiki/Digital_humanities"
USER_AGENT = "CharlesBot/0.1 (+email:charles.pletcher@tufts.edu)"

def make_request(url: str) -> requests.Response:
    return requests.get(url, headers={"User-Agent": USER_AGENT})

def save_node_and_return_links(response: requests.Response):
    node = create_node(response)

    MY_NETWORK.append(node)

    return node["links"]


def main():
    response = make_request(STARTING_URL)
    depth = 0
    links = deque(save_node_and_return_links(response))

    while depth <= 5:
        next_links = deque()

        for link in links:
            time.sleep(0.5)
            response = make_request(link)

            here_links = save_node_and_return_links(response)

            random_link = random.choice(here_links)

            next_links.append(random_link)

        depth += 1
        links = next_links

        print(f"current depth: {depth}")
        print([node["title"] for node in MY_NETWORK])


main()
# Out:
# current depth: 1
# ['Digital humanities', 'Topic model', 'Data and information visualization', 'Computer cartography', 'Electronic publishing', 'Konrad Zuse', 'Probabilistic latent semantic analysis', 'The Pennsylvania Gazette', 'Proceedings of the National Academy of Sciences of the United States of America', 'Digital object identifier', 'Semantic Scholar', 'Visualization (graphics)', 'Formal concept analysis', 'Object–role modeling', 'Correlation', 'Augmented reality', 'Geographic information system', 'Waldo R. Tobler', 'Geographic information system', '3D scanning', 'Laptop', 'ebook', 'Scientific literature', 'Peer review', 'Academic journal', 'University of Illinois Chicago', 'Helios AG', 'Konrad Zuse', 'Industrial process control', 'Braniewo', 'Henschel & Son', 'Statistical hypothesis test', 'Latent and observable variables', 'Latent and observable variables', 'Expectation–maximization algorithm', 'Information filtering system', 'Stamp Act 1765', 'Cyclopædia, or an Universal Dictionary of Arts and Sciences', 'Political cartoon', 'The Saturday Evening Post', 'Wisconsin Historical Society', 'National Academy of Sciences, India', 'PNA', 'Academic discipline', 'National Academy of Sciences', 'Hybrid open-access journal', 'Case sensitivity', 'Persistent uniform resource locator', 'HTTP', 'Publications Office of the European Union', 'OECD', 'Allen Institute for AI', 'Earth science', 'Medical literature', 'Digital object identifier', 'PubMed', 'Visualization', 'Finite element method', 'Visualization (graphics)', 'Medical imaging', 'Perspective (graphical)', 'Ontology (information science)', 'Lattice (order)', 'Semantic Web', 'Binary relation', 'Duality (mathematics)', 'Domain of discourse', 'Business rule', 'Eckhard D. Falkenberg', 'G. M. Nijssen', 'G. M. Nijssen', 'Correlation (disambiguation)', 'Pearson correlation coefficient', 'Pearson correlation coefficient', 'Pearson correlation coefficient', 'Random variable', 'Wikipedia:Summary style', 'Wikipedia:Content forks', 'Visual system', 'Virtual fixture', 'Outline of object recognition', 'GIS (disambiguation)', 'Geographic information science', 'Coordinate system', 'Elevation', 'Edmund William Gilbert', 'Cartography', 'Geographic information system', 'Department of Geography (University of Washington)', 'Emeritus', 'National Academies of Sciences, Engineering, and Medicine', 'GIS (disambiguation)', 'Geographic information science', 'Coordinate system', 'Elevation', 'Edmund William Gilbert', '3D modeling', 'Industrial computed tomography', 'Nondestructive testing', 'Prosthesis', 'Prototype', 'Laptop (disambiguation)', 'Flat-panel display', 'Computer monitor', 'Keyboard technology', 'Business travel', 'Bob Brown (writer)', 'Sound film', 'Disc jockey', 'File Retrieval and Editing System', 'Hyperlink', 'Academic publishing', 'Academic journal', 'Primary source', 'Wikipedia:Manual of Style/Lists', 'Wikipedia:Manual of Style/Lists', 'Peer review (disambiguation)', 'Academic discipline', 'Academy', 'Academic publishing', 'Conference proceedings', 'Periodical literature', 'Academic publishing', 'Research', 'Scientific literature', 'Philosophical Transactions of the Royal Society', 'University of Illinois Urbana-Champaign', 'Public university', 'Chancellor (education)', 'Coordinates information', 'University of Illinois System', 'Konrad Zuse', 'ISBN', 'ISBN', 'Siemens', 'Siemens', 'Helios AG', 'Konrad Zuse', 'Industrial process control', 'Industrial process control', 'Factory', 'Final product', 'Ctesibius', 'Hero of Alexandria', 'Proportional–integral–derivative controller']
# current depth: 2
# ['Digital humanities', 'Topic model', 'Data and information visualization', 'Computer cartography', 'Electronic publishing', 'Konrad Zuse', 'Probabilistic latent semantic analysis', 'The Pennsylvania Gazette', 'Proceedings of the National Academy of Sciences of the United States of America', 'Digital object identifier', 'Semantic Scholar', 'Visualization (graphics)', 'Formal concept analysis', 'Object–role modeling', 'Correlation', 'Augmented reality', 'Geographic information system', 'Waldo R. Tobler', 'Geographic information system', '3D scanning', 'Laptop', 'ebook', 'Scientific literature', 'Peer review', 'Academic journal', 'University of Illinois Chicago', 'Helios AG', 'Konrad Zuse', 'Industrial process control', 'Braniewo', 'Henschel & Son', 'Statistical hypothesis test', 'Latent and observable variables', 'Latent and observable variables', 'Expectation–maximization algorithm', 'Information filtering system', 'Stamp Act 1765', 'Cyclopædia, or an Universal Dictionary of Arts and Sciences', 'Political cartoon', 'The Saturday Evening Post', 'Wisconsin Historical Society', 'National Academy of Sciences, India', 'PNA', 'Academic discipline', 'National Academy of Sciences', 'Hybrid open-access journal', 'Case sensitivity', 'Persistent uniform resource locator', 'HTTP', 'Publications Office of the European Union', 'OECD', 'Allen Institute for AI', 'Earth science', 'Medical literature', 'Digital object identifier', 'PubMed', 'Visualization', 'Finite element method', 'Visualization (graphics)', 'Medical imaging', 'Perspective (graphical)', 'Ontology (information science)', 'Lattice (order)', 'Semantic Web', 'Binary relation', 'Duality (mathematics)', 'Domain of discourse', 'Business rule', 'Eckhard D. Falkenberg', 'G. M. Nijssen', 'G. M. Nijssen', 'Correlation (disambiguation)', 'Pearson correlation coefficient', 'Pearson correlation coefficient', 'Pearson correlation coefficient', 'Random variable', 'Wikipedia:Summary style', 'Wikipedia:Content forks', 'Visual system', 'Virtual fixture', 'Outline of object recognition', 'GIS (disambiguation)', 'Geographic information science', 'Coordinate system', 'Elevation', 'Edmund William Gilbert', 'Cartography', 'Geographic information system', 'Department of Geography (University of Washington)', 'Emeritus', 'National Academies of Sciences, Engineering, and Medicine', 'GIS (disambiguation)', 'Geographic information science', 'Coordinate system', 'Elevation', 'Edmund William Gilbert', '3D modeling', 'Industrial computed tomography', 'Nondestructive testing', 'Prosthesis', 'Prototype', 'Laptop (disambiguation)', 'Flat-panel display', 'Computer monitor', 'Keyboard technology', 'Business travel', 'Bob Brown (writer)', 'Sound film', 'Disc jockey', 'File Retrieval and Editing System', 'Hyperlink', 'Academic publishing', 'Academic journal', 'Primary source', 'Wikipedia:Manual of Style/Lists', 'Wikipedia:Manual of Style/Lists', 'Peer review (disambiguation)', 'Academic discipline', 'Academy', 'Academic publishing', 'Conference proceedings', 'Periodical literature', 'Academic publishing', 'Research', 'Scientific literature', 'Philosophical Transactions of the Royal Society', 'University of Illinois Urbana-Champaign', 'Public university', 'Chancellor (education)', 'Coordinates information', 'University of Illinois System', 'Konrad Zuse', 'ISBN', 'ISBN', 'Siemens', 'Siemens', 'Helios AG', 'Konrad Zuse', 'Industrial process control', 'Industrial process control', 'Factory', 'Final product', 'Ctesibius', 'Hero of Alexandria', 'Proportional–integral–derivative controller', 'Process manufacturing', 'Work in process', 'Ancient Greek', 'Ancient Greek mathematics', 'Output device']
# current depth: 3
# ['Digital humanities', 'Topic model', 'Data and information visualization', 'Computer cartography', 'Electronic publishing', 'Konrad Zuse', 'Probabilistic latent semantic analysis', 'The Pennsylvania Gazette', 'Proceedings of the National Academy of Sciences of the United States of America', 'Digital object identifier', 'Semantic Scholar', 'Visualization (graphics)', 'Formal concept analysis', 'Object–role modeling', 'Correlation', 'Augmented reality', 'Geographic information system', 'Waldo R. Tobler', 'Geographic information system', '3D scanning', 'Laptop', 'ebook', 'Scientific literature', 'Peer review', 'Academic journal', 'University of Illinois Chicago', 'Helios AG', 'Konrad Zuse', 'Industrial process control', 'Braniewo', 'Henschel & Son', 'Statistical hypothesis test', 'Latent and observable variables', 'Latent and observable variables', 'Expectation–maximization algorithm', 'Information filtering system', 'Stamp Act 1765', 'Cyclopædia, or an Universal Dictionary of Arts and Sciences', 'Political cartoon', 'The Saturday Evening Post', 'Wisconsin Historical Society', 'National Academy of Sciences, India', 'PNA', 'Academic discipline', 'National Academy of Sciences', 'Hybrid open-access journal', 'Case sensitivity', 'Persistent uniform resource locator', 'HTTP', 'Publications Office of the European Union', 'OECD', 'Allen Institute for AI', 'Earth science', 'Medical literature', 'Digital object identifier', 'PubMed', 'Visualization', 'Finite element method', 'Visualization (graphics)', 'Medical imaging', 'Perspective (graphical)', 'Ontology (information science)', 'Lattice (order)', 'Semantic Web', 'Binary relation', 'Duality (mathematics)', 'Domain of discourse', 'Business rule', 'Eckhard D. Falkenberg', 'G. M. Nijssen', 'G. M. Nijssen', 'Correlation (disambiguation)', 'Pearson correlation coefficient', 'Pearson correlation coefficient', 'Pearson correlation coefficient', 'Random variable', 'Wikipedia:Summary style', 'Wikipedia:Content forks', 'Visual system', 'Virtual fixture', 'Outline of object recognition', 'GIS (disambiguation)', 'Geographic information science', 'Coordinate system', 'Elevation', 'Edmund William Gilbert', 'Cartography', 'Geographic information system', 'Department of Geography (University of Washington)', 'Emeritus', 'National Academies of Sciences, Engineering, and Medicine', 'GIS (disambiguation)', 'Geographic information science', 'Coordinate system', 'Elevation', 'Edmund William Gilbert', '3D modeling', 'Industrial computed tomography', 'Nondestructive testing', 'Prosthesis', 'Prototype', 'Laptop (disambiguation)', 'Flat-panel display', 'Computer monitor', 'Keyboard technology', 'Business travel', 'Bob Brown (writer)', 'Sound film', 'Disc jockey', 'File Retrieval and Editing System', 'Hyperlink', 'Academic publishing', 'Academic journal', 'Primary source', 'Wikipedia:Manual of Style/Lists', 'Wikipedia:Manual of Style/Lists', 'Peer review (disambiguation)', 'Academic discipline', 'Academy', 'Academic publishing', 'Conference proceedings', 'Periodical literature', 'Academic publishing', 'Research', 'Scientific literature', 'Philosophical Transactions of the Royal Society', 'University of Illinois Urbana-Champaign', 'Public university', 'Chancellor (education)', 'Coordinates information', 'University of Illinois System', 'Konrad Zuse', 'ISBN', 'ISBN', 'Siemens', 'Siemens', 'Helios AG', 'Konrad Zuse', 'Industrial process control', 'Industrial process control', 'Factory', 'Final product', 'Ctesibius', 'Hero of Alexandria', 'Proportional–integral–derivative controller', 'Process manufacturing', 'Work in process', 'Ancient Greek', 'Ancient Greek mathematics', 'Output device', 'Chemical substance', 'Work in Progress (disambiguation)', 'Aeolic Greek', 'Mediterranean Sea', 'Central processing unit']
# current depth: 4
# ['Digital humanities', 'Topic model', 'Data and information visualization', 'Computer cartography', 'Electronic publishing', 'Konrad Zuse', 'Probabilistic latent semantic analysis', 'The Pennsylvania Gazette', 'Proceedings of the National Academy of Sciences of the United States of America', 'Digital object identifier', 'Semantic Scholar', 'Visualization (graphics)', 'Formal concept analysis', 'Object–role modeling', 'Correlation', 'Augmented reality', 'Geographic information system', 'Waldo R. Tobler', 'Geographic information system', '3D scanning', 'Laptop', 'ebook', 'Scientific literature', 'Peer review', 'Academic journal', 'University of Illinois Chicago', 'Helios AG', 'Konrad Zuse', 'Industrial process control', 'Braniewo', 'Henschel & Son', 'Statistical hypothesis test', 'Latent and observable variables', 'Latent and observable variables', 'Expectation–maximization algorithm', 'Information filtering system', 'Stamp Act 1765', 'Cyclopædia, or an Universal Dictionary of Arts and Sciences', 'Political cartoon', 'The Saturday Evening Post', 'Wisconsin Historical Society', 'National Academy of Sciences, India', 'PNA', 'Academic discipline', 'National Academy of Sciences', 'Hybrid open-access journal', 'Case sensitivity', 'Persistent uniform resource locator', 'HTTP', 'Publications Office of the European Union', 'OECD', 'Allen Institute for AI', 'Earth science', 'Medical literature', 'Digital object identifier', 'PubMed', 'Visualization', 'Finite element method', 'Visualization (graphics)', 'Medical imaging', 'Perspective (graphical)', 'Ontology (information science)', 'Lattice (order)', 'Semantic Web', 'Binary relation', 'Duality (mathematics)', 'Domain of discourse', 'Business rule', 'Eckhard D. Falkenberg', 'G. M. Nijssen', 'G. M. Nijssen', 'Correlation (disambiguation)', 'Pearson correlation coefficient', 'Pearson correlation coefficient', 'Pearson correlation coefficient', 'Random variable', 'Wikipedia:Summary style', 'Wikipedia:Content forks', 'Visual system', 'Virtual fixture', 'Outline of object recognition', 'GIS (disambiguation)', 'Geographic information science', 'Coordinate system', 'Elevation', 'Edmund William Gilbert', 'Cartography', 'Geographic information system', 'Department of Geography (University of Washington)', 'Emeritus', 'National Academies of Sciences, Engineering, and Medicine', 'GIS (disambiguation)', 'Geographic information science', 'Coordinate system', 'Elevation', 'Edmund William Gilbert', '3D modeling', 'Industrial computed tomography', 'Nondestructive testing', 'Prosthesis', 'Prototype', 'Laptop (disambiguation)', 'Flat-panel display', 'Computer monitor', 'Keyboard technology', 'Business travel', 'Bob Brown (writer)', 'Sound film', 'Disc jockey', 'File Retrieval and Editing System', 'Hyperlink', 'Academic publishing', 'Academic journal', 'Primary source', 'Wikipedia:Manual of Style/Lists', 'Wikipedia:Manual of Style/Lists', 'Peer review (disambiguation)', 'Academic discipline', 'Academy', 'Academic publishing', 'Conference proceedings', 'Periodical literature', 'Academic publishing', 'Research', 'Scientific literature', 'Philosophical Transactions of the Royal Society', 'University of Illinois Urbana-Champaign', 'Public university', 'Chancellor (education)', 'Coordinates information', 'University of Illinois System', 'Konrad Zuse', 'ISBN', 'ISBN', 'Siemens', 'Siemens', 'Helios AG', 'Konrad Zuse', 'Industrial process control', 'Industrial process control', 'Factory', 'Final product', 'Ctesibius', 'Hero of Alexandria', 'Proportional–integral–derivative controller', 'Process manufacturing', 'Work in process', 'Ancient Greek', 'Ancient Greek mathematics', 'Output device', 'Chemical substance', 'Work in Progress (disambiguation)', 'Aeolic Greek', 'Mediterranean Sea', 'Central processing unit', 'Water', 'Man Alive (band)', 'Ancient Greek dialects', 'List of seas on Earth', 'Processor design']
# current depth: 5
# ['Digital humanities', 'Topic model', 'Data and information visualization', 'Computer cartography', 'Electronic publishing', 'Konrad Zuse', 'Probabilistic latent semantic analysis', 'The Pennsylvania Gazette', 'Proceedings of the National Academy of Sciences of the United States of America', 'Digital object identifier', 'Semantic Scholar', 'Visualization (graphics)', 'Formal concept analysis', 'Object–role modeling', 'Correlation', 'Augmented reality', 'Geographic information system', 'Waldo R. Tobler', 'Geographic information system', '3D scanning', 'Laptop', 'ebook', 'Scientific literature', 'Peer review', 'Academic journal', 'University of Illinois Chicago', 'Helios AG', 'Konrad Zuse', 'Industrial process control', 'Braniewo', 'Henschel & Son', 'Statistical hypothesis test', 'Latent and observable variables', 'Latent and observable variables', 'Expectation–maximization algorithm', 'Information filtering system', 'Stamp Act 1765', 'Cyclopædia, or an Universal Dictionary of Arts and Sciences', 'Political cartoon', 'The Saturday Evening Post', 'Wisconsin Historical Society', 'National Academy of Sciences, India', 'PNA', 'Academic discipline', 'National Academy of Sciences', 'Hybrid open-access journal', 'Case sensitivity', 'Persistent uniform resource locator', 'HTTP', 'Publications Office of the European Union', 'OECD', 'Allen Institute for AI', 'Earth science', 'Medical literature', 'Digital object identifier', 'PubMed', 'Visualization', 'Finite element method', 'Visualization (graphics)', 'Medical imaging', 'Perspective (graphical)', 'Ontology (information science)', 'Lattice (order)', 'Semantic Web', 'Binary relation', 'Duality (mathematics)', 'Domain of discourse', 'Business rule', 'Eckhard D. Falkenberg', 'G. M. Nijssen', 'G. M. Nijssen', 'Correlation (disambiguation)', 'Pearson correlation coefficient', 'Pearson correlation coefficient', 'Pearson correlation coefficient', 'Random variable', 'Wikipedia:Summary style', 'Wikipedia:Content forks', 'Visual system', 'Virtual fixture', 'Outline of object recognition', 'GIS (disambiguation)', 'Geographic information science', 'Coordinate system', 'Elevation', 'Edmund William Gilbert', 'Cartography', 'Geographic information system', 'Department of Geography (University of Washington)', 'Emeritus', 'National Academies of Sciences, Engineering, and Medicine', 'GIS (disambiguation)', 'Geographic information science', 'Coordinate system', 'Elevation', 'Edmund William Gilbert', '3D modeling', 'Industrial computed tomography', 'Nondestructive testing', 'Prosthesis', 'Prototype', 'Laptop (disambiguation)', 'Flat-panel display', 'Computer monitor', 'Keyboard technology', 'Business travel', 'Bob Brown (writer)', 'Sound film', 'Disc jockey', 'File Retrieval and Editing System', 'Hyperlink', 'Academic publishing', 'Academic journal', 'Primary source', 'Wikipedia:Manual of Style/Lists', 'Wikipedia:Manual of Style/Lists', 'Peer review (disambiguation)', 'Academic discipline', 'Academy', 'Academic publishing', 'Conference proceedings', 'Periodical literature', 'Academic publishing', 'Research', 'Scientific literature', 'Philosophical Transactions of the Royal Society', 'University of Illinois Urbana-Champaign', 'Public university', 'Chancellor (education)', 'Coordinates information', 'University of Illinois System', 'Konrad Zuse', 'ISBN', 'ISBN', 'Siemens', 'Siemens', 'Helios AG', 'Konrad Zuse', 'Industrial process control', 'Industrial process control', 'Factory', 'Final product', 'Ctesibius', 'Hero of Alexandria', 'Proportional–integral–derivative controller', 'Process manufacturing', 'Work in process', 'Ancient Greek', 'Ancient Greek mathematics', 'Output device', 'Chemical substance', 'Work in Progress (disambiguation)', 'Aeolic Greek', 'Mediterranean Sea', 'Central processing unit', 'Water', 'Man Alive (band)', 'Ancient Greek dialects', 'List of seas on Earth', 'Processor design', 'Water (disambiguation)', 'Open Surgery', 'Mycenaean Greece', 'Seas (disambiguation)', 'Semiconductor device ...
# current depth: 6
# ['Digital humanities', 'Topic model', 'Data and information visualization', 'Computer cartography', 'Electronic publishing', 'Konrad Zuse', 'Probabilistic latent semantic analysis', 'The Pennsylvania Gazette', 'Proceedings of the National Academy of Sciences of the United States of America', 'Digital object identifier', 'Semantic Scholar', 'Visualization (graphics)', 'Formal concept analysis', 'Object–role modeling', 'Correlation', 'Augmented reality', 'Geographic information system', 'Waldo R. Tobler', 'Geographic information system', '3D scanning', 'Laptop', 'ebook', 'Scientific literature', 'Peer review', 'Academic journal', 'University of Illinois Chicago', 'Helios AG', 'Konrad Zuse', 'Industrial process control', 'Braniewo', 'Henschel & Son', 'Statistical hypothesis test', 'Latent and observable variables', 'Latent and observable variables', 'Expectation–maximization algorithm', 'Information filtering system', 'Stamp Act 1765', 'Cyclopædia, or an Universal Dictionary of Arts and Sciences', 'Political cartoon', 'The Saturday Evening Post', 'Wisconsin Historical Society', 'National Academy of Sciences, India', 'PNA', 'Academic discipline', 'National Academy of Sciences', 'Hybrid open-access journal', 'Case sensitivity', 'Persistent uniform resource locator', 'HTTP', 'Publications Office of the European Union', 'OECD', 'Allen Institute for AI', 'Earth science', 'Medical literature', 'Digital object identifier', 'PubMed', 'Visualization', 'Finite element method', 'Visualization (graphics)', 'Medical imaging', 'Perspective (graphical)', 'Ontology (information science)', 'Lattice (order)', 'Semantic Web', 'Binary relation', 'Duality (mathematics)', 'Domain of discourse', 'Business rule', 'Eckhard D. Falkenberg', 'G. M. Nijssen', 'G. M. Nijssen', 'Correlation (disambiguation)', 'Pearson correlation coefficient', 'Pearson correlation coefficient', 'Pearson correlation coefficient', 'Random variable', 'Wikipedia:Summary style', 'Wikipedia:Content forks', 'Visual system', 'Virtual fixture', 'Outline of object recognition', 'GIS (disambiguation)', 'Geographic information science', 'Coordinate system', 'Elevation', 'Edmund William Gilbert', 'Cartography', 'Geographic information system', 'Department of Geography (University of Washington)', 'Emeritus', 'National Academies of Sciences, Engineering, and Medicine', 'GIS (disambiguation)', 'Geographic information science', 'Coordinate system', 'Elevation', 'Edmund William Gilbert', '3D modeling', 'Industrial computed tomography', 'Nondestructive testing', 'Prosthesis', 'Prototype', 'Laptop (disambiguation)', 'Flat-panel display', 'Computer monitor', 'Keyboard technology', 'Business travel', 'Bob Brown (writer)', 'Sound film', 'Disc jockey', 'File Retrieval and Editing System', 'Hyperlink', 'Academic publishing', 'Academic journal', 'Primary source', 'Wikipedia:Manual of Style/Lists', 'Wikipedia:Manual of Style/Lists', 'Peer review (disambiguation)', 'Academic discipline', 'Academy', 'Academic publishing', 'Conference proceedings', 'Periodical literature', 'Academic publishing', 'Research', 'Scientific literature', 'Philosophical Transactions of the Royal Society', 'University of Illinois Urbana-Champaign', 'Public university', 'Chancellor (education)', 'Coordinates information', 'University of Illinois System', 'Konrad Zuse', 'ISBN', 'ISBN', 'Siemens', 'Siemens', 'Helios AG', 'Konrad Zuse', 'Industrial process control', 'Industrial process control', 'Factory', 'Final product', 'Ctesibius', 'Hero of Alexandria', 'Proportional–integral–derivative controller', 'Process manufacturing', 'Work in process', 'Ancient Greek', 'Ancient Greek mathematics', 'Output device', 'Chemical substance', 'Work in Progress (disambiguation)', 'Aeolic Greek', 'Mediterranean Sea', 'Central processing unit', 'Water', 'Man Alive (band)', 'Ancient Greek dialects', 'List of seas on Earth', 'Processor design', 'Water (disambiguation)', 'Open Surgery', 'Mycenaean Greece', 'Seas (disambiguation)', 'Semiconductor device ...
